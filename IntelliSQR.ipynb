# %%
# !pip install PyPDF2
# Out:
# ...
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -arkupsafe (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rkupsafe (c:\programdata\anaconda3\lib\site-packages)
# ...

# %%
import pandas as pd

# %%
import PyPDF2

# %%
file=open("_Sample Debate File_savead pdf.pdf","rb")

# %%
reader=PyPDF2.PdfFileReader(file)

# %%
print(reader.numPages)
# Out:
# 42

# %%
page1=reader.getPage(19)

# %%
p1=page1.extractText()

# %%
page2=reader.getPage(20)

# %%
p2=page2.extractText()

# %%
page3=reader.getPage(21)

# %%
p3=page3.extractText()

# %%
page4=reader.getPage(22)

# %%
p4=page4.extractText()

# %%
page5=reader.getPage(23)

# %%
p5=page5.extractText()

# %%
page6=reader.getPage(24)

# %%
p6=page6.extractText()

# %%
page7=reader.getPage(25)

# %%
p7=page7.extractText()

# %%
page8=reader.getPage(26)

# %%
p8=page8.extractText()

# %%
page9=reader.getPage(27)

# %%
p9=page9.extractText()

# %%
page10=reader.getPage(28)

# %%
p10=page10.extractText()

# %%
text=p1+p2+p3+p4+p5+p6+p7+p8+p9+p10

# %%
print(text)
# Out:
# 2
# 7 Oral Answers AUGUST 21,1990 Oral Answers  28
# o
# pment of thd country, consumption of power
# is also increasing. I would like to know from
# the hon. Minister whether the Government is
# ready to go in for small power projects to
# remove the existing shortage of power and
# expedite the construction work of these
# projects since the big power projects take a
# long time and require heavy investment. Is
# the Government prepared to take up small
# and medium projects in Rajasthan and
# Madhya Pradesh also to expedite the work
# of power generation in these States.
# [English]
# SHRI DINESH GOSWAMI: Sir, when
# we have got resource constraint and re-
# sources are to be utilised in the best manner
# possible, obviously varbus factors are taken
# into consideration including the factor which
# has been mentioned by the hon. Member.
# SHRIMATI VASUNDHARA RAJE: Sir,
# the hon. Minister has very beautifully put his
# answer together conce'^ning the Dolphur
# ...

# %%
import re
pattern = re.compile('(([ A-Z])+[:])')

headings = []

for match in pattern.finditer(text):
    s=match.start()
    e = match.end()
    headings.append(text[s:e].replace('\n',''))  

print(headings)
# Out:
# ['SHRI DINESH GOSWAMI:', 'SHRIMATI VASUNDHARA RAJE:', 'SHRI DINESH GOSWAMI:', 'SHRI SHOPAT SINGH MAKKASAR:', 'SHRI DINESH GOSWAMI:', ' SPEAKER:', 'SHRI DINESH GOSWAMI:', ' RASA SINGH RAWAT:', 'SHRI DAULAT RAM SARAN:', 'SHRI DINESH GOSWAMI:', ' PUTTE GOWDA:', 'SHRI BANWARILAL PUROHIT:', 'SHRI D M  PUTTE GOWDA:', ' GURUPADASWAMY:', ' PUTTE GOWDA:', ' GURUPADASWAMY:', 'SHRI BANWARILAL PUROHIT:', 'SHRI KALKA DAS:', ' SPEAKER:', 'SHRI BANWARILAL PUROHIT:', 'SHRI BANWARILAL PUROHIT:', ' GURUPADASWAMY:', ' DEBIPROSAD PAL:', ' GURUPADASWAMY:', 'SHRI INORAJIT GUPTA:', ' GURUPADASWAMY:', 'SHRI BHABANI SHANKAR HOTA:', ' GURUPADASWAMY:', ' GURUPADASWAMY:', 'DEYA:', 'WAL:', ' LAXINARAYAN PANDEYA:', 'SHRI DINESH GOSWAMI:', 'SHRI DINESH GOSWAMI:', 'SHRI DINESH GOSWAMI:', ' SHRIANADICHARAN DAS:', ' SHRI LARANG SAI:', 'SHRI RESHAM LAL JANGDE:', ' SHRI SURESH KODIKKUNNIL:', ' BASHEER:', 'BRAHMBATT:']

# %%
headings
# Out:
# ['SHRI DINESH GOSWAMI:',
#  'SHRIMATI VASUNDHARA RAJE:',
#  'SHRI DINESH GOSWAMI:',
#  'SHRI SHOPAT SINGH MAKKASAR:',
#  'SHRI DINESH GOSWAMI:',
#  ' SPEAKER:',
#  'SHRI DINESH GOSWAMI:',
#  ' RASA SINGH RAWAT:',
#  'SHRI DAULAT RAM SARAN:',
#  'SHRI DINESH GOSWAMI:',
#  ' PUTTE GOWDA:',
#  'SHRI BANWARILAL PUROHIT:',
#  'SHRI D M  PUTTE GOWDA:',
#  ' GURUPADASWAMY:',
#  ' PUTTE GOWDA:',
#  ' GURUPADASWAMY:',
#  'SHRI BANWARILAL PUROHIT:',
#  'SHRI KALKA DAS:',
#  ' SPEAKER:',
#  'SHRI BANWARILAL PUROHIT:',
#  'SHRI BANWARILAL PUROHIT:',
#  ' GURUPADASWAMY:',
#  ' DEBIPROSAD PAL:',
#  ' GURUPADASWAMY:',
#  'SHRI INORAJIT GUPTA:',
#  ' GURUPADASWAMY:',
#  'SHRI BHABANI SHANKAR HOTA:',
#  ' GURUPADASWAMY:',
#  ' GURUPADASWAMY:',
#  'DEYA:',
#  'WAL:',
#  ' LAXINARAYAN PANDEYA:',
#  'SHRI DINESH GOSWAMI:',
#  'SHRI DINESH GOSWAMI:',
#  'SHRI DINESH GOSWAMI:',
#  ' SHRIANADICHARAN DAS:',
#  ' SHRI LARANG SAI:',
#  'SHRI RESHAM LAL JANGDE:',
#  ' SHRI SURESH KODIKKUNNIL:',
# ...
